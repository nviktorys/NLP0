# %% [markdown]
# #Git commit changes

# %% [markdown]
# ##Connect to drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pwd
# Change directory
# %cd ../content/gdrive/MyDrive/Colab Notebooks/Kaggle/NLP0
# !pwd
# Out:
# /content
# /content/gdrive/MyDrive/Colab Notebooks/Kaggle/NLP0
# /content/gdrive/MyDrive/Colab Notebooks/Kaggle/NLP0

# %% [markdown]
# ##Connect to Git

# %%
# !git config --global user.email "{user.emai}"
# !git config --global user.name "{user.name}"

# %% [markdown]
# ## Check connection to remote

# %%
# Check for existing SSH keys
# Lists the files in your .ssh directory, if they exist
# !ls -al "/content/gdrive/MyDrive/Colab Notebooks/Kaggle/NLP0/.ssh"
# !ls -al /root/.ssh

# %%
# Copy gitconfig / .ssh key
#!cp ~/.gitconfig "/content/gdrive/MyDrive/Colab Notebooks/Kaggle/NLP0/.gitconfig"
#!cp -r "/content/gdrive/MyDrive/Colab Notebooks/Kaggle/NLP0/.ssh/" /root/

# %%
# Test ssh
# !ssh -T git@github.com
# Out:
# Hi nviktorys! You've successfully authenticated, but GitHub does not provide shell access.

# %% [markdown]
# ##Reset SSH key remote repo if didn't authenticate in previous step

# %%
# Set origin
#!git remote set-url origin git@github.com:nviktorys/NLP0.git

# %%
# Generate SSH key
# !ssh-keygen -t rsa -b 4096

# %%
# Add SSH key fingerprints to the known_hosts file-
# !ssh-keyscan -t rsa github.com >> "/content/gdrive/MyDrive/Colab Notebooks/Kaggle/NLP0/.ssh/known_hosts"
# Out:
# # github.com:22 SSH-2.0-babeld-4f04c79d

# %%
# Show SSH key
# !cat "/content/gdrive/MyDrive/Colab Notebooks/Kaggle/NLP0/.ssh/id_rsa.pub"
# Out:
# ssh-rsa ... root@7829a59cf83d

# %%
# Check for existing SSH keys
# Lists the files in your .ssh directory, if they exist
# !ls -al "/content/gdrive/MyDrive/Colab Notebooks/Kaggle/NLP0/.ssh"
# !ls -al /root/.ssh

# %%
# Copy gitconfig / .ssh key
#!cp ~/.gitconfig "/content/gdrive/MyDrive/Colab Notebooks/Kaggle/NLP0/.gitconfig"
#!cp -r "/content/gdrive/MyDrive/Colab Notebooks/Kaggle/NLP0/.ssh/" /root/

# %%
# Test ssh
# !ssh -T git@github.com
# Out:
# ...
# Hi nviktorys! You've successfully authenticated, but GitHub does not provide shell access.

# %%
# Debug
# !ssh -vT git@github.com

# %% [markdown]
# ##Commit changes to local repo

# %%
# !git status
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
# !git add .
# !git commit -m 'Update'
# Out:
# [master 1612eed] Update
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %% [markdown]
# ##Sync local and remote repos

# %%
# View existing remotes
# !git remote -v
# Out:
# nlp0	https://github.com/nviktorys/NLP0.git (fetch)
# nlp0	https://github.com/nviktorys/NLP0.git (push)
# origin	git@github.com:nviktorys/NLP0.git (fetch)
# origin	git@github.com:nviktorys/NLP0.git (push)

# %%
# Copy remote repo
# !git fetch nlp0

# %%
# Compare remote and local
# !git diff nlp0/master

# %%
# !git checkout master

# %%
# !git commit -m 'Update'
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
# !git merge nlp0/master
# Out:
# Already up to date.

# %% [markdown]
# ## Push to remote

# %%
# !git push origin master
# Out:
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !git push nlp0 master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git remote show nlp0
# Out:
# * remote nlp0
#   Fetch URL: https://github.com/nviktorys/NLP0.git
#   Push  URL: https://github.com/nviktorys/NLP0.git
#   HEAD branch: master
#   Remote branch:
#     master tracked
#   Local ref configured for 'git push':
#     master pushes to master (fast-forwardable)

# %%
# !git config --global url."git@gitlab.com:".insteadOf "https://gitlab.com/"

# %%
# !cat "/content/gdrive/MyDrive/Colab Notebooks/Kaggle/NLP0/.gitconfig"
# Out:
# [user]
# 	email = {user.emai}
# 	name = {user.name}
# 	password = Telmana35!(!

# %%
# !git config --list --show-origin
# Out:
# file:/root/.gitconfig	user.email={user.emai}
# file:/root/.gitconfig	user.name={user.name}
# file:/root/.gitconfig	user.password=Telmana35!(!
# file:.git/config	core.repositoryformatversion=0
# file:.git/config	core.filemode=true
# file:.git/config	core.bare=false
# file:.git/config	core.logallrefupdates=true
# file:.git/config	remote.nlp0.url=https://github.com/nviktorys/NLP0.git
# file:.git/config	remote.nlp0.fetch=+refs/heads/*:refs/remotes/nlp0/*
# file:.git/config	credential.helper=store
# file:.git/config	remote.origin.url=git@github.com:nviktorys/NLP0.git
# file:.git/config	remote.origin.fetch=+refs/heads/*:refs/remotes/origin/*
