# %% [markdown]
# # Kaggle set-up

# %%
import os

# %% [markdown]
# Create kaggle.json

# %%
# %cd ~/
# %mkdir ~/.kaggle
# !touch ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
import json
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Load data from Kaggle

# %%
# !pwd
# Out:
# /content

# %%
# Change directory
# %cd ../content/drive/MyDrive/Colab Notebooks/Kaggle/NLP0
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/Kaggle/NLP0
# /content/drive/MyDrive/Colab Notebooks/Kaggle/NLP0

# %%
# !!! use your credentials
os.environ['KAGGLE_USERNAME'] = 'kaggle.name' # use your kaggle name
os.environ['KAGGLE_KEY'] = 'kaggle.key' # key from kaggle.json

# %%
#!pip install kaggle
#!cd ~/.kaggle
# !kaggle competitions download -c nlp-getting-started
# Out:
# Downloading nlp-getting-started.zip to /content/drive/MyDrive/Colab Notebooks/Kaggle/NLP0
#   0% 0.00/593k [00:00<?, ?B/s]
# 100% 593k/593k [00:00<00:00, 18.7MB/s]

# %% [markdown]
# # Create Git repository

# %% [markdown]
# ## Generate SSH Key

# %%
# !ssh-keygen -t rsa -b 4096

# %%
# Add SSH key fingerprints to the known_hosts file-
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts

# %%
# add the newly created SSH key to the Github account
# !cat /root/.ssh/id_rsa.pub
# add this key to https://github.com/settings/keys -> new SSH key

# %%
# Test ssh
# !ssh -T git@github.com

# %% [markdown]
# ## Link to remote repository

# %%
# !!! use your credentials
#!git remote rm origin
#!git remote set-url origin git@github.com:gitusername/NLP0.git
# !git remote show origin

# %% [markdown]
# ## Initialise local repository

# %%
#!git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/Kaggle/NLP0/.git/

# %%
# !!! use your credentials
#!git config --global user.email "user@gmail.com"
#!git config --global user.name "userid"

# %%
# %ls -a
# Out:
# 01_Import_data.ipynb  kaggle.json  nlp-getting-started.zip
# .git/                 NLP0/        nlp_git/

# %%
# !git status

# %%
# !git add .

# %%
# !git status
# Out:
# On branch master
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	modified:   00_Setup.ipynb

# %%
# !git commit -m 'Initial commit, set-up kaggle and GIT'
# Out:
# [master 51b6af4] Initial commit, set-up kaggle and GIT
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite 00_Setup.ipynb (84%)

# %%
# !git push origin master
