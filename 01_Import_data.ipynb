# %% [markdown]
# # New section

# %%
import os

# %% [markdown]
# Create kaggle.json

# %%
# %cd ~/
# %mkdir ~/.kaggle
# !touch ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
import json
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Load data from Kaggle

# %%
# Change directory
# %cd ../content/drive/MyDrive/Colab Notebooks/Kaggle/NLP0
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/Kaggle/NLP0
# /content/drive/MyDrive/Colab Notebooks/Kaggle/NLP0

# %%
os.environ['KAGGLE_USERNAME'] = 'viktorian'
os.environ['KAGGLE_KEY'] = 'f69511432fe2dbab2274adef5a8d2657'

# %%
#!pip install kaggle
#!cd ~/.kaggle
# !kaggle competitions download -c nlp-getting-started
# Out:
# Downloading nlp-getting-started.zip to /content/drive/MyDrive/Colab Notebooks/Kaggle/NLP0
#   0% 0.00/593k [00:00<?, ?B/s]
# 100% 593k/593k [00:00<00:00, 18.7MB/s]

# %%
# !git clone https://github.com/nviktorys/NLP0.git
# Out:
# Cloning into 'NLP0'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), done.

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/Kaggle/NLP0/nlp_git/.git/

# %%
# %cd nlp_git
# Out:
# /content/drive/MyDrive/Colab Notebooks/Kaggle/NLP0/nlp_git

# %%
# %ls -a
# Out:
# .git/

# %%
# !git status
# !git add .
# !git status
# Out:
# On branch master
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)
# On branch master
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !pwd
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# pwd: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
